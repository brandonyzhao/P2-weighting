# %%
from tqdm.auto import tqdm

import numpy as np
import matplotlib.pyplot as plt

# %%
samples = np.load('./samples/test.npy')

# %%
print(samples.shape)
# Out:
# (20, 1, 128, 128)

# %%
plt.figure(figsize=[20, 25])
for i in range(20):
    plt.subplot(4, 5, i+1)
    im = plt.imshow(samples[i].squeeze())
    plt.colorbar(im)
    plt.axis('off')

# %%
cube = np.load('/srv/tmp/brandon/pm_dataset_planes_3/pm_%04d.npy'%0)
print(cube.shape)
# Out:
# (20, 128, 128)

# %%
gt = np.load('./results/darkmatter_darkmatter_no_noise_sigma=1_pnp-edm-edm-rho0=10-rhomin=0.1_shear/gt/00000.npy')

# %%
plt.figure(figsize=[20, 25])
for i in range(len(gt)):
    plt.subplot(4, 5, i+1)
    im = plt.imshow(gt[i].squeeze() * 10)#, vmin=samples.min(), vmax = samples.max())
    plt.colorbar(im)
    plt.axis('off')
